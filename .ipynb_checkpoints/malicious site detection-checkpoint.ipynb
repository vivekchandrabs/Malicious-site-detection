# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.metrics import accuracy_score
# %matplotlib inline

regressor = LogisticRegression()
scalar = MinMaxScaler()

# %%
data_set = pd.read_csv("dataset.csv")

# %%
data_set
# Out:
#           URL  URL_LENGTH  NUMBER_SPECIAL_CHARACTERS     CHARSET  \
# 0      M0_109          16                          7  iso-8859-1
# 1     B0_2314          16                          6       UTF-8
# 2      B0_911          16                          6    us-ascii
# 3      B0_113          17                          6  ISO-8859-1
# 4      B0_403          17                          6       UTF-8
# 5     B0_2064          18                          7       UTF-8
# 6      B0_462          18                          6  iso-8859-1
# 7     B0_1128          19                          6    us-ascii
# 8       M2_17          20                          5       utf-8
# 9       M3_75          20                          5       utf-8
# 10    B0_1013          20                          6       utf-8
# 11    B0_1102          20                          6    us-ascii
# 12      B0_22          20                          7       utf-8
# ...

# %%
data =  data_set.drop(['URL','Type'], axis = 1)

# %%
target = data_set['Type']

# %%
correlation = data_set.corr('spearman')

# %%
correlation
# Out:
#                            URL_LENGTH  NUMBER_SPECIAL_CHARACTERS  \
# URL_LENGTH                   1.000000                   0.894917
# NUMBER_SPECIAL_CHARACTERS    0.894917                   1.000000
# CONTENT_LENGTH               0.184256                   0.189176
# TCP_CONVERSATION_EXCHANGE   -0.060893                  -0.028492
# DIST_REMOTE_TCP_PORT        -0.018788                  -0.038339
# REMOTE_IPS                  -0.052774                  -0.020638
# APP_BYTES                   -0.057973                  -0.023926
# SOURCE_APP_PACKETS          -0.064104                  -0.028200
# REMOTE_APP_PACKETS          -0.033647                   0.001885
# SOURCE_APP_BYTES            -0.036125                  -0.004046
# REMOTE_APP_BYTES            -0.060952                  -0.025209
# APP_PACKETS                 -0.064104                  -0.028200
# DNS_QUERY_TIMES             -0.073569                  -0.018290
# ...

# %%
abs(correlation['Type']).sort_values()
# Out:
# APP_BYTES                    0.004821
# TCP_CONVERSATION_EXCHANGE    0.005659
# SOURCE_APP_PACKETS           0.009457
# APP_PACKETS                  0.009457
# REMOTE_APP_BYTES             0.014563
# REMOTE_IPS                   0.039148
# URL_LENGTH                   0.046539
# REMOTE_APP_PACKETS           0.069727
# SOURCE_APP_BYTES             0.081915
# DNS_QUERY_TIMES              0.092924
# CONTENT_LENGTH               0.126721
# DIST_REMOTE_TCP_PORT         0.203741
# NUMBER_SPECIAL_CHARACTERS    0.227702
# Type                         1.000000
# Name: Type, dtype: float64

# %%
correlation = data_set.corr('pearson')

# %%
correlation
# Out:
#                            URL_LENGTH  NUMBER_SPECIAL_CHARACTERS  \
# URL_LENGTH                   1.000000                   0.917986
# NUMBER_SPECIAL_CHARACTERS    0.917986                   1.000000
# CONTENT_LENGTH               0.129745                   0.214225
# TCP_CONVERSATION_EXCHANGE   -0.038407                  -0.037459
# DIST_REMOTE_TCP_PORT        -0.039839                  -0.042619
# REMOTE_IPS                  -0.046367                  -0.047103
# APP_BYTES                   -0.026446                  -0.023914
# SOURCE_APP_PACKETS          -0.042264                  -0.040096
# REMOTE_APP_PACKETS          -0.033779                  -0.030597
# SOURCE_APP_BYTES            -0.014857                  -0.014376
# REMOTE_APP_BYTES            -0.026686                  -0.024098
# APP_PACKETS                 -0.042264                  -0.040096
# DNS_QUERY_TIMES             -0.068582                  -0.050048
# ...

# %%
abs(correlation['Type']).sort_values()
# Out:
# REMOTE_APP_BYTES             0.011004
# APP_BYTES                    0.011262
# REMOTE_APP_PACKETS           0.032897
# SOURCE_APP_PACKETS           0.034414
# APP_PACKETS                  0.034414
# TCP_CONVERSATION_EXCHANGE    0.040202
# SOURCE_APP_BYTES             0.043852
# DNS_QUERY_TIMES              0.068753
# REMOTE_IPS                   0.078783
# DIST_REMOTE_TCP_PORT         0.082925
# CONTENT_LENGTH               0.090852
# URL_LENGTH                   0.162104
# NUMBER_SPECIAL_CHARACTERS    0.280897
# Type                         1.000000
# Name: Type, dtype: float64

# %%
x = scalar.fit_transform(x)

# %%
x = data_set[['NUMBER_SPECIAL_CHARACTERS']]
x = scalar.fit_transform(x)
y = target
plt.plot(x,y,'r.')

# %%
x = data_set[['URL_LENGTH']]
x = scalar.fit_transform(x)
y = target
plt.plot(x,y,'r.')

# %%
x = data_set[['CONTENT_LENGTH']]
x = scalar.fit_transform(x)
y = target
plt.plot(x,y,'r.')
